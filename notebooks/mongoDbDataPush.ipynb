# %% [markdown]
# ## Pushing Data to MongoDb Atlas

# %%
import pandas as pd
import numpy as np
import sys
from dotenv import load_dotenv
load_dotenv()
from pymongo import MongoClient

# %%
import os
# %pwd
# Out:
# 'e:\\end-to-end-machine-learning-project\\Predict-Laptops-Price\\notebooks'

# %%
df = pd.read_csv('laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.shape
# Out:
# (1303, 12)

# %%
# Convert the dataframe into dict
data_dict = df.to_dict(orient = "records")
data_dict
# Out:
# [{'Unnamed: 0': 0,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Retina Display 2560x1600',
#   'Cpu': 'Intel Core i5 2.3GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel Iris Plus Graphics 640',
#   'OpSys': 'macOS',
#   'Weight': '1.37kg',
#   'Price': 71378.6832},
#  {'Unnamed: 0': 1,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': '1440x900',
#   'Cpu': 'Intel Core i5 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '128GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 6000',
#   'OpSys': 'macOS',
#   'Weight': '1.34kg',
#   'Price': 47895.5232},
#  {'Unnamed: 0': 2,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'No OS',
#   'Weight': '1.86kg',
#   'Price': 30636.0},
#  {'Unnamed: 0': 3,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.4,
#   'ScreenResolution': 'IPS Panel Retina Display 2880x1800',
#   'Cpu': 'Intel Core i7 2.7GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'AMD Radeon Pro 455',
#   'OpSys': 'macOS',
#   'Weight': '1.83kg',
#   'Price': 135195.33599999998},
#  {'Unnamed: 0': 4,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Retina Display 2560x1600',
#   'Cpu': 'Intel Core i5 3.1GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel Iris Plus Graphics 650',
#   'OpSys': 'macOS',
#   'Weight': '1.37kg',
#   'Price': 96095.808},
#  {'Unnamed: 0': 5,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'AMD A9-Series 9420 3GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'AMD Radeon R5',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 21312.0},
#  {'Unnamed: 0': 6,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.4,
#   'ScreenResolution': 'IPS Panel Retina Display 2880x1800',
#   'Cpu': 'Intel Core i7 2.2GHz',
#   'Ram': '16GB',
#   'Memory': '256GB Flash Storage',
#   'Gpu': 'Intel Iris Pro Graphics',
#   'OpSys': 'Mac OS X',
#   'Weight': '2.04kg',
#   'Price': 114017.6016},
#  {'Unnamed: 0': 7,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': '1440x900',
#   'Cpu': 'Intel Core i5 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 6000',
#   'OpSys': 'macOS',
#   'Weight': '1.34kg',
#   'Price': 61735.536},
#  {'Unnamed: 0': 8,
#   'Company': 'Asus',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Nvidia GeForce MX150',
#   'OpSys': 'Windows 10',
#   'Weight': '1.3kg',
#   'Price': 79653.59999999999},
#  {'Unnamed: 0': 9,
#   'Company': 'Acer',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.6kg',
#   'Price': 41025.6},
#  {'Unnamed: 0': 10,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'No OS',
#   'Weight': '1.86kg',
#   'Price': 20986.992},
#  {'Unnamed: 0': 11,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'No OS',
#   'Weight': '1.86kg',
#   'Price': 18381.0672},
#  {'Unnamed: 0': 12,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.4,
#   'ScreenResolution': 'IPS Panel Retina Display 2880x1800',
#   'Cpu': 'Intel Core i7 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon Pro 555',
#   'OpSys': 'macOS',
#   'Weight': '1.83kg',
#   'Price': 130001.6016},
#  {'Unnamed: 0': 13,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon R5 M430',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 26581.392},
#  {'Unnamed: 0': 14,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 12.0,
#   'ScreenResolution': 'IPS Panel Retina Display 2304x1440',
#   'Cpu': 'Intel Core M m3 1.2GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 615',
#   'OpSys': 'macOS',
#   'Weight': '0.92kg',
#   'Price': 67260.672},
#  {'Unnamed: 0': 15,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Retina Display 2560x1600',
#   'Cpu': 'Intel Core i5 2.3GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel Iris Plus Graphics 640',
#   'OpSys': 'macOS',
#   'Weight': '1.37kg',
#   'Price': 80908.344},
#  {'Unnamed: 0': 16,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon R5 M430',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 39693.6},
#  {'Unnamed: 0': 17,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.4,
#   'ScreenResolution': 'IPS Panel Retina Display 2880x1800',
#   'Cpu': 'Intel Core i7 2.9GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'AMD Radeon Pro 560',
#   'OpSys': 'macOS',
#   'Weight': '1.83kg',
#   'Price': 152274.24},
#  {'Unnamed: 0': 18,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 7100U 2.4GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce 940MX',
#   'OpSys': 'No OS',
#   'Weight': '2.2kg',
#   'Price': 26586.72},
#  {'Unnamed: 0': 19,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.22kg',
#   'Price': 52161.12},
#  {'Unnamed: 0': 20,
#   'Company': 'Asus',
#   'TypeName': 'Netbook',
#   'Inches': 11.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Atom x5-Z8350 1.44GHz',
#   'Ram': '2GB',
#   'Memory': '32GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 400',
#   'OpSys': 'Windows 10',
#   'Weight': '0.98kg',
#   'Price': 10224.432},
#  {'Unnamed: 0': 21,
#   'Company': 'Lenovo',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7300HQ 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050',
#   'OpSys': 'Windows 10',
#   'Weight': '2.5kg',
#   'Price': 53226.72},
#  {'Unnamed: 0': 22,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'AMD E-Series E2-9000e 1.5GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'AMD Radeon R2',
#   'OpSys': 'No OS',
#   'Weight': '1.86kg',
#   'Price': 13746.24},
#  {'Unnamed: 0': 23,
#   'Company': 'Dell',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 13.3,
#   'ScreenResolution': 'Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.62kg',
#   'Price': 43636.32},
#  {'Unnamed: 0': 24,
#   'Company': 'HP',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.91kg',
#   'Price': 35111.52},
#  {'Unnamed: 0': 25,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '2.3kg',
#   'Price': 22305.1392},
#  {'Unnamed: 0': 26,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': '1440x900',
#   'Cpu': 'Intel Core i5 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '128GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 6000',
#   'OpSys': 'Mac OS X',
#   'Weight': '1.35kg',
#   'Price': 58554.72},
#  {'Unnamed: 0': 27,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 42624.0},
#  {'Unnamed: 0': 28,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8650U 1.9GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD +  256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.88kg',
#   'Price': 69157.44},
#  {'Unnamed: 0': 29,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce 930MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2.5kg',
#   'Price': 47738.88},
#  {'Unnamed: 0': 30,
#   'Company': 'Chuwi',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Atom x5-Z8300 1.44GHz',
#   'Ram': '4GB',
#   'Memory': '64GB Flash Storage',
#   'Gpu': 'Intel HD Graphics',
#   'OpSys': 'Windows 10',
#   'Weight': '1.89kg',
#   'Price': 13053.0672},
#  {'Unnamed: 0': 31,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'AMD E-Series E2-6110 1.5GHz',
#   'Ram': '2GB',
#   'Memory': '32GB Flash Storage',
#   'Gpu': 'AMD Radeon R2',
#   'OpSys': 'Windows 10',
#   'Weight': '1.65kg',
#   'Price': 10602.72},
#  {'Unnamed: 0': 32,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'AMD A6-Series 9220 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '2.71kg',
#   'Price': 23389.92},
#  {'Unnamed: 0': 33,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Touchscreen / Quad HD+ 3200x1800',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.2kg',
#   'Price': 99580.32},
#  {'Unnamed: 0': 34,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': '1440x900',
#   'Cpu': 'Intel Core i5 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 6000',
#   'OpSys': 'Mac OS X',
#   'Weight': '1.35kg',
#   'Price': 53173.44},
#  {'Unnamed: 0': 35,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Celeron Dual Core N3350 1.1GHz',
#   'Ram': '4GB',
#   'Memory': '64GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 500',
#   'OpSys': 'Windows 10',
#   'Weight': '1.44kg',
#   'Price': 13266.72},
#  {'Unnamed: 0': 36,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i3 7130U 2.7GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Linux',
#   'Weight': '2.1kg',
#   'Price': 19553.76},
#  {'Unnamed: 0': 37,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '2.8kg',
#   'Price': 52161.12},
#  {'Unnamed: 0': 38,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.86kg',
#   'Price': 26037.4032},
#  {'Unnamed: 0': 39,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce 930MX ',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 46833.12},
#  {'Unnamed: 0': 40,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Linux',
#   'Weight': '2kg',
#   'Price': 20725.92},
#  {'Unnamed: 0': 41,
#   'Company': 'Dell',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1060',
#   'OpSys': 'Windows 10',
#   'Weight': '2.65kg',
#   'Price': 79866.72},
#  {'Unnamed: 0': 42,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce 940MX',
#   'OpSys': 'Linux',
#   'Weight': '2.3kg',
#   'Price': 27864.9072},
#  {'Unnamed: 0': 43,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 36336.96},
#  {'Unnamed: 0': 44,
#   'Company': 'Dell',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '12GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce 150MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2.77kg',
#   'Price': 53226.72},
#  {'Unnamed: 0': 45,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Retina Display 2560x1600',
#   'Cpu': 'Intel Core i5 2.0GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel Iris Graphics 540',
#   'OpSys': 'macOS',
#   'Weight': '1.37kg',
#   'Price': 75604.31999999999},
#  {'Unnamed: 0': 46,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'No OS',
#   'Weight': '2.2kg',
#   'Price': 19660.32},
#  {'Unnamed: 0': 47,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'AMD Ryzen 1700 3GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'AMD Radeon RX 580',
#   'OpSys': 'Windows 10',
#   'Weight': '3.2kg',
#   'Price': 69210.72},
#  {'Unnamed: 0': 48,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon R5 M430',
#   'OpSys': 'Windows 10',
#   'Weight': '2.3kg',
#   'Price': 34045.92},
#  {'Unnamed: 0': 49,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Pentium Quad Core N4200 1.1GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce 920MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2.8kg',
#   'Price': 24828.48},
#  {'Unnamed: 0': 50,
#   'Company': 'Lenovo',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 10.1,
#   'ScreenResolution': 'IPS Panel Touchscreen 1920x1200',
#   'Cpu': 'Intel Atom x5-Z8550 1.44GHz',
#   'Ram': '4GB',
#   'Memory': '64GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 400',
#   'OpSys': 'Android',
#   'Weight': '0.69kg',
#   'Price': 16996.32},
#  {'Unnamed: 0': 51,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce MX150',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 44808.48},
#  {'Unnamed: 0': 52,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'AMD A6-Series 9220 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon R4 Graphics',
#   'OpSys': 'Windows 10',
#   'Weight': '1.86kg',
#   'Price': 21231.5472},
#  {'Unnamed: 0': 53,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.49kg',
#   'Price': 58767.84},
#  {'Unnamed: 0': 54,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i3 7100U 2.4GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.4kg',
#   'Price': 20459.52},
#  {'Unnamed: 0': 55,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon 520',
#   'OpSys': 'Windows 10',
#   'Weight': '2.13kg',
#   'Price': 40908.384},
#  {'Unnamed: 0': 56,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.91kg',
#   'Price': 23389.92},
#  {'Unnamed: 0': 57,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2kg',
#   'Price': 31232.203200000004},
#  {'Unnamed: 0': 58,
#   'Company': 'MSI',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  2TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1070',
#   'OpSys': 'Windows 10',
#   'Weight': '2.43kg',
#   'Price': 130482.72},
#  {'Unnamed: 0': 59,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Linux',
#   'Weight': '2kg',
#   'Price': 22111.2},
#  {'Unnamed: 0': 60,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  2TB HDD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '2.8kg',
#   'Price': 69210.72},
#  {'Unnamed: 0': 61,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.7kg',
#   'Price': 46833.12},
#  {'Unnamed: 0': 62,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 7130U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'No OS',
#   'Weight': '1.7kg',
#   'Price': 31914.72},
#  {'Unnamed: 0': 63,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.4kg',
#   'Price': 50136.48},
#  {'Unnamed: 0': 64,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.86kg',
#   'Price': 36763.2},
#  {'Unnamed: 0': 65,
#   'Company': 'Asus',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Nvidia GeForce GTX 1050 Ti',
#   'OpSys': 'Windows 10',
#   'Weight': '1.8kg',
#   'Price': 105654.24},
#  {'Unnamed: 0': 66,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'AMD Radeon 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.86kg',
#   'Price': 23373.4032},
#  {'Unnamed: 0': 67,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz',
#   'Ram': '4GB',
#   'Memory': '32GB SSD',
#   'Gpu': 'Intel HD Graphics 400',
#   'OpSys': 'Windows 10',
#   'Weight': '1.44kg',
#   'Price': 12201.12},
#  {'Unnamed: 0': 68,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.9kg',
#   'Price': 29250.72},
#  {'Unnamed: 0': 69,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '12GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050 Ti',
#   'OpSys': 'Linux',
#   'Weight': '3kg',
#   'Price': 50562.72},
#  {'Unnamed: 0': 70,
#   'Company': 'Microsoft',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.5,
#   'ScreenResolution': 'Touchscreen 2256x1504',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10 S',
#   'Weight': '1.252kg',
#   'Price': 58021.92},
#  {'Unnamed: 0': 71,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '1.4kg',
#   'Price': 50882.4},
#  {'Unnamed: 0': 72,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 46353.6},
#  {'Unnamed: 0': 73,
#   'Company': 'MSI',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7300HQ 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050',
#   'OpSys': 'Windows 10',
#   'Weight': '2.7kg',
#   'Price': 58341.6},
#  {'Unnamed: 0': 74,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 20725.92},
#  {'Unnamed: 0': 75,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 50562.72},
#  {'Unnamed: 0': 76,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '2TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'No OS',
#   'Weight': '2.2kg',
#   'Price': 27652.32},
#  {'Unnamed: 0': 77,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.02kg',
#   'Price': 45554.4},
#  {'Unnamed: 0': 78,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 7130U 2.7GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce MX130',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 28238.4},
#  {'Unnamed: 0': 79,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce 930MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2.5kg',
#   'Price': 52054.56},
#  {'Unnamed: 0': 80,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.88kg',
#   'Price': 58403.4048},
#  {'Unnamed: 0': 81,
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 12.0,
#   'ScreenResolution': 'IPS Panel Retina Display 2304x1440',
#   'Cpu': 'Intel Core i5 1.3GHz',
#   'Ram': '8GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel HD Graphics 615',
#   'OpSys': 'macOS',
#   'Weight': '0.92kg',
#   'Price': 80452.8},
#  {'Unnamed: 0': 82,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.63kg',
#   'Price': 45820.8},
#  {'Unnamed: 0': 83,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'AMD A6-Series 9220 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'AMD R4 Graphics',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 21258.72},
#  {'Unnamed: 0': 84,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'AMD A9-Series 9420 3GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'AMD Radeon R5',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 21045.6},
#  {'Unnamed: 0': 85,
#   'Company': 'Dell',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050 Ti',
#   'OpSys': 'Windows 10',
#   'Weight': '2.65kg',
#   'Price': 71874.72},
#  {'Unnamed: 0': 86,
#   'Company': 'HP',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce GTX 940MX',
#   'OpSys': 'Windows 10',
#   'Weight': '1.83kg',
#   'Price': 37242.72},
#  {'Unnamed: 0': 87,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.96kg',
#   'Price': 31914.1872},
#  {'Unnamed: 0': 88,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1060',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 77202.72},
#  {'Unnamed: 0': 89,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.21kg',
#   'Price': 87858.72},
#  {'Unnamed: 0': 90,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'AMD FX 9830P 3GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'AMD Radeon RX 560',
#   'OpSys': 'Windows 10',
#   'Weight': '2.45kg',
#   'Price': 37242.72},
#  {'Unnamed: 0': 91,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce MX150',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 36709.92},
#  {'Unnamed: 0': 92,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.49kg',
#   'Price': 63776.16},
#  {'Unnamed: 0': 93,
#   'Company': 'Dell',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7300HQ 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce GTX 1060',
#   'OpSys': 'Windows 10',
#   'Weight': '2.65kg',
#   'Price': 63669.6},
#  {'Unnamed: 0': 94,
#   'Company': 'Asus',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.25kg',
#   'Price': 55890.72},
#  {'Unnamed: 0': 95,
#   'Company': 'Acer',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.5kg',
#   'Price': 45128.16},
#  {'Unnamed: 0': 96,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'AMD Radeon R5 M430',
#   'OpSys': 'Linux',
#   'Weight': '2.2kg',
#   'Price': 31962.672},
#  {'Unnamed: 0': 97,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon R5 M430',
#   'OpSys': 'Linux',
#   'Weight': '2.2kg',
#   'Price': 25840.8},
#  {'Unnamed: 0': 98,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 7100U 2.4GHz',
#   'Ram': '6GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce 920M',
#   'OpSys': 'Windows 10',
#   'Weight': '2kg',
#   'Price': 30742.56},
#  {'Unnamed: 0': 99,
#   'Company': 'HP',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '12GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050',
#   'OpSys': 'Windows 10',
#   'Weight': '2.62kg',
#   'Price': 66546.72},
#  {'Unnamed: 0': 100,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '1.91kg',
#   'Price': 38308.32},
#  {'Unnamed: 0': 101,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'AMD E-Series E2-9000e 1.5GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'AMD Radeon R2',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 18594.72},
#  {'Unnamed: 0': 102,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'AMD Radeon 520',
#   'OpSys': 'Linux',
#   'Weight': '2.2kg',
#   'Price': 34472.16},
#  {'Unnamed: 0': 103,
#   'Company': 'HP',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce MX150',
#   'OpSys': 'Windows 10',
#   'Weight': '1.38kg',
#   'Price': 59620.32},
#  {'Unnamed: 0': 104,
#   'Company': 'Microsoft',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.5,
#   'ScreenResolution': 'Touchscreen 2256x1504',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10 S',
#   'Weight': '1.252kg',
#   'Price': 71395.2},
#  {'Unnamed: 0': 105,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '6GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce 940MX',
#   'OpSys': 'Windows 10',
#   'Weight': '1.58kg',
#   'Price': 35111.52},
#  {'Unnamed: 0': 106,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.85kg',
#   'Price': 22105.872},
#  {'Unnamed: 0': 107,
#   'Company': 'Asus',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce 940MX',
#   'OpSys': 'Windows 10',
#   'Weight': '1.3kg',
#   'Price': 63563.04},
#  {'Unnamed: 0': 108,
#   'Company': 'MSI',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050 Ti',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 69210.72},
#  {'Unnamed: 0': 109,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.58kg',
#   'Price': 78854.4},
#  {'Unnamed: 0': 110,
#   'Company': 'Asus',
#   'TypeName': 'Ultrabook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce MX150',
#   'OpSys': 'Windows 10',
#   'Weight': '1.5kg',
#   'Price': 67239.36},
#  {'Unnamed: 0': 111,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Quad HD+ / Touchscreen 3200x1800',
#   'Cpu': 'Intel Core i7 7560U 2.4GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel Iris Plus Graphics 640',
#   'OpSys': 'Windows 10',
#   'Weight': '1.23kg',
#   'Price': 73473.12},
#  {'Unnamed: 0': 112,
#   'Company': 'Lenovo',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.37kg',
#   'Price': 74538.72},
#  {'Unnamed: 0': 113,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel 1366x768',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.63kg',
#   'Price': 38468.16},
#  {'Unnamed: 0': 114,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.21kg',
#   'Price': 86793.12},
#  {'Unnamed: 0': 115,
#   'Company': 'HP',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.26kg',
#   'Price': 74538.1872},
#  {'Unnamed: 0': 116,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.63kg',
#   'Price': 57755.52},
#  {'Unnamed: 0': 117,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce 940MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2.16kg',
#   'Price': 60223.98239999999},
#  {'Unnamed: 0': 118,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce 920MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2kg',
#   'Price': 30049.92},
#  {'Unnamed: 0': 119,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce 940MX',
#   'OpSys': 'Windows 10',
#   'Weight': '1.7kg',
#   'Price': 59567.04},
#  {'Unnamed: 0': 120,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i3 7100U 2.4GHz',
#   'Ram': '6GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 25521.12},
#  {'Unnamed: 0': 121,
#   'Company': 'MSI',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  2TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1070',
#   'OpSys': 'Windows 10',
#   'Weight': '1.8kg',
#   'Price': 119427.12},
#  {'Unnamed: 0': 122,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce 940MX',
#   'OpSys': 'No OS',
#   'Weight': '2.2kg',
#   'Price': 33513.119999999995},
#  {'Unnamed: 0': 123,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Nvidia GeForce 930MX ',
#   'OpSys': 'Windows 10',
#   'Weight': '2.5kg',
#   'Price': 67718.88},
#  {'Unnamed: 0': 124,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'AMD A9-Series 9420 3GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon R5',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 24029.28},
#  {'Unnamed: 0': 125,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel HD Graphics 400',
#   'OpSys': 'No OS',
#   'Weight': '1.86kg',
#   'Price': 13799.52},
#  {'Unnamed: 0': 126,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.63kg',
#   'Price': 43263.36},
#  {'Unnamed: 0': 127,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'AMD E-Series 6110 1.5GHz',
#   'Ram': '4GB',
#   'Memory': '64GB SSD',
#   'Gpu': 'AMD Radeon R2',
#   'OpSys': 'Windows 10 S',
#   'Weight': '1.65kg',
#   'Price': 14811.3072},
#  {'Unnamed: 0': 128,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  2TB HDD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '2.8kg',
#   'Price': 74378.87999999999},
#  {'Unnamed: 0': 129,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.5kg',
#   'Price': 49443.84},
#  {'Unnamed: 0': 130,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'AMD Radeon R7 M445',
#   'OpSys': 'Windows 10',
#   'Weight': '2.36kg',
#   'Price': 34045.3872},
#  {'Unnamed: 0': 131,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'AMD Radeon R5 M430',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 23922.72},
#  {'Unnamed: 0': 132,
#   'Company': 'Acer',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.6kg',
#   'Price': 47099.52},
#  {'Unnamed: 0': 133,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 7130U 2.7GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce MX130',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 30476.16},
#  {'Unnamed: 0': 134,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.05kg',
#   'Price': 31861.44},
#  {'Unnamed: 0': 135,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.63kg',
#   'Price': 52640.64},
#  {'Unnamed: 0': 136,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Celeron Dual Core N3350 1.1GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 500',
#   'OpSys': 'No OS',
#   'Weight': '1.9kg',
#   'Price': 13445.7408},
#  {'Unnamed: 0': 137,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7300HQ 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050',
#   'OpSys': 'Windows 10',
#   'Weight': '3kg',
#   'Price': 49976.64},
#  {'Unnamed: 0': 138,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce 920MX',
#   'OpSys': 'No OS',
#   'Weight': '2.2kg',
#   'Price': 26586.72},
#  {'Unnamed: 0': 139,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.32kg',
#   'Price': 37242.72},
#  {'Unnamed: 0': 140,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 17.3,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 7130U 2.7GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce MX130',
#   'OpSys': 'Windows 10',
#   'Weight': '3kg',
#   'Price': 34898.4},
#  {'Unnamed: 0': 141,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 8250U 1.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon RX 550',
#   'OpSys': 'Windows 10',
#   'Weight': '1.75kg',
#   'Price': 59461.5456},
#  {'Unnamed: 0': 142,
#   'Company': 'Lenovo',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce GTX 1050M',
#   'OpSys': 'No OS',
#   'Weight': '2.4kg',
#   'Price': 46300.32},
#  {'Unnamed: 0': 143,
#   'Company': 'Toshiba',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 6200U 2.3GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 32074.56},
#  {'Unnamed: 0': 144,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'AMD A6-Series 9220 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon R4 Graphics',
#   'OpSys': 'Windows 10',
#   'Weight': '1.86kg',
#   'Price': 19660.32},
#  {'Unnamed: 0': 145,
#   'Company': 'Asus',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 8550U 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel UHD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.25kg',
#   'Price': 58554.72},
#  {'Unnamed: 0': 146,
#   'Company': 'HP',
#   'TypeName': 'Ultrabook',
#   'Inches': 12.5,
#   'ScreenResolution': 'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#   'Cpu': 'Intel Core M 6Y75 1.2GHz',
#   'Ram': '8GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel HD Graphics 515',
#   'OpSys': 'Windows 10',
#   'Weight': '0.97kg',
#   'Price': 107305.92},
#  {'Unnamed: 0': 147,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Celeron Dual Core N3350 1.1GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 500',
#   'OpSys': 'Windows 10',
#   'Weight': '2kg',
#   'Price': 18328.32},
#  {'Unnamed: 0': 148,
#   'Company': 'MSI',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1070',
#   'OpSys': 'Windows 10',
#   'Weight': '2.9kg',
#   'Price': 108105.12},
#  {'Unnamed: 0': 149,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 23816.16},
#  {'Unnamed: 0': 150,
#   'Company': 'Dell',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Nvidia GeForce GTX 1050',
#   'OpSys': 'Windows 10',
#   'Weight': '2.56kg',
#   'Price': 66560.5728},
#  {'Unnamed: 0': 151,
#   'Company': 'Dell',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '8GB',
#   'Memory': '1.0TB Hybrid',
#   'Gpu': 'Nvidia GeForce GTX 1050',
#   'OpSys': 'Windows 10',
#   'Weight': '2.62kg',
#   'Price': 47898.72},
#  {'Unnamed: 0': 152,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.9kg',
# ...
#   'Price': 18594.72},
#  {'Unnamed: 0': 950,
#   'Company': 'HP',
#   'TypeName': 'Workstation',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 6820HQ 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '8GB SSD',
#   'Gpu': 'Nvidia Quadro M1000M',
#   'OpSys': 'Windows 10',
#   'Weight': '2.0kg',
#   'Price': 119826.72},
#  {'Unnamed: 0': 951,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7600U 2.8GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.36kg',
#   'Price': 94572.0},
#  {'Unnamed: 0': 952,
#   'Company': 'Toshiba',
#   'TypeName': 'Notebook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 6200U 2.3GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 7',
#   'Weight': '1.2kg',
#   'Price': 77788.8},
#  {'Unnamed: 0': 953,
#   'Company': 'Asus',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 12.5,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core M M7-6Y75 1.2GHz',
#   'Ram': '8GB',
#   'Memory': '64GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 515',
#   'OpSys': 'Chrome OS',
#   'Weight': '1.2kg',
#   'Price': 61751.52},
#  {'Unnamed: 0': 954,
#   'Company': 'Lenovo',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 6600U 2.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.7kg',
#   'Price': 79333.3872},
#  {'Unnamed: 0': 955,
#   'Company': 'Dell',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'IPS Panel 4K Ultra HD 3840x2160',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1070',
#   'OpSys': 'Windows 10',
#   'Weight': '4.36kg',
#   'Price': 168045.12},
#  {'Unnamed: 0': 956,
#   'Company': 'Dell',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 13.3,
#   'ScreenResolution': 'Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i5 7Y54 1.2GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 615',
#   'OpSys': 'Windows 10',
#   'Weight': '1.24kg',
#   'Price': 101178.72},
#  {'Unnamed: 0': 957,
#   'Company': 'HP',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 11.6,
#   'ScreenResolution': 'Touchscreen 1366x768',
#   'Cpu': 'Intel Pentium Quad Core N4200 1.1GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 505',
#   'OpSys': 'Windows 10',
#   'Weight': '1.45kg',
#   'Price': 41292.0},
#  {'Unnamed: 0': 958,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Quad HD+ 3200x1800',
#   'Cpu': 'Intel Core i7 6500U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.3kg',
#   'Price': 67559.04},
#  {'Unnamed: 0': 959,
#   'Company': 'Acer',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 11.6,
#   'ScreenResolution': 'IPS Panel Touchscreen 1366x768',
#   'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz',
#   'Ram': '4GB',
#   'Memory': '32GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 400',
#   'OpSys': 'Chrome OS',
#   'Weight': '1.25kg',
#   'Price': 20725.92},
#  {'Unnamed: 0': 960,
#   'Company': 'Toshiba',
#   'TypeName': 'Notebook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 6300U 2.4GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.2kg',
#   'Price': 81784.8},
#  {'Unnamed: 0': 961,
#   'Company': 'Lenovo',
#   'TypeName': 'Ultrabook',
#   'Inches': 12.5,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7300U 2.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.36kg',
#   'Price': 93772.8},
#  {'Unnamed: 0': 962,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '12GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 950M',
#   'OpSys': 'Windows 10',
#   'Weight': '2.4kg',
#   'Price': 53759.52},
#  {'Unnamed: 0': 963,
#   'Company': 'Toshiba',
#   'TypeName': 'Ultrabook',
#   'Inches': 12.5,
#   'ScreenResolution': 'Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.1kg',
#   'Price': 95371.2},
#  {'Unnamed: 0': 964,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.50GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Nvidia GeForce 930MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2.04kg',
#   'Price': 45101.52},
#  {'Unnamed: 0': 965,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i3 6006U 2.0GHz',
#   'Ram': '4GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'AMD Radeon R5 M430',
#   'OpSys': 'Linux',
#   'Weight': '2.25kg',
#   'Price': 24808.2336},
#  {'Unnamed: 0': 966,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.9kg',
#   'Price': 43956.0},
#  {'Unnamed: 0': 967,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 7100U 2.4GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.04kg',
#   'Price': 36496.8},
#  {'Unnamed: 0': 968,
#   'Company': 'Dell',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '32GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1070',
#   'OpSys': 'Windows 10',
#   'Weight': '4.42kg',
#   'Price': 167778.72},
#  {'Unnamed: 0': 969,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '6GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Nvidia GeForce 920MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2.4kg',
#   'Price': 37029.6},
#  {'Unnamed: 0': 970,
#   'Company': 'Dell',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 13.3,
#   'ScreenResolution': 'Quad HD+ / Touchscreen 3200x1800',
#   'Cpu': 'Intel Core i7 7Y75 1.3GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel HD Graphics 615',
#   'OpSys': 'Windows 10',
#   'Weight': '1.22kg',
#   'Price': 101178.72},
#  {'Unnamed: 0': 971,
#   'Company': 'Dell',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Touchscreen 2560x1440',
#   'Cpu': 'Intel Core i7 6600U 2.6GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.5kg',
#   'Price': 104587.57439999998},
#  {'Unnamed: 0': 972,
#   'Company': 'Dell',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 6700HQ 2.6GHz',
#   'Ram': '32GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1070',
#   'OpSys': 'Windows 10',
#   'Weight': '4.42kg',
#   'Price': 149184.0},
#  {'Unnamed: 0': 973,
#   'Company': 'Toshiba',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 6200U 2.3GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.95kg',
#   'Price': 62870.4},
#  {'Unnamed: 0': 974,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1060',
#   'OpSys': 'Windows 10',
#   'Weight': '2.73kg',
#   'Price': 109218.672},
#  {'Unnamed: 0': 975,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.70GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce 930MX',
#   'OpSys': 'Windows 10',
#   'Weight': '2.04kg',
#   'Price': 52161.12},
#  {'Unnamed: 0': 976,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 6200U 2.3GHz',
#   'Ram': '4GB',
#   'Memory': '508GB Hybrid',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 7',
#   'Weight': '1.70kg',
#   'Price': 53386.56},
#  {'Unnamed: 0': 977,
#   'Company': 'Asus',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 15.6,
#   'ScreenResolution': '4K Ultra HD / Touchscreen 3840x2160',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '16GB',
#   'Memory': '512GB SSD +  2TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 950M',
#   'OpSys': 'Windows 10',
#   'Weight': '2.3kg',
#   'Price': 95850.72},
#  {'Unnamed: 0': 978,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '6GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.04kg',
#   'Price': 30849.12},
#  {'Unnamed: 0': 979,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 17.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050 Ti',
#   'OpSys': 'Windows 10',
#   'Weight': '2.99kg',
#   'Price': 93186.72},
#  {'Unnamed: 0': 980,
#   'Company': 'Dell',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '12GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.19kg',
#   'Price': 69210.72},
#  {'Unnamed: 0': 981,
#   'Company': 'Toshiba',
#   'TypeName': 'Notebook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 6200U 2.3GHz',
#   'Ram': '4GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 7',
#   'Weight': '1.2kg',
#   'Price': 63669.6},
#  {'Unnamed: 0': 982,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'AMD A12-Series 9720P 3.6GHz',
#   'Ram': '6GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'AMD Radeon 530',
#   'OpSys': 'Windows 10',
#   'Weight': '2.2kg',
#   'Price': 29250.72},
#  {'Unnamed: 0': 983,
#   'Company': 'Fujitsu',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 6200U 2.3GHz',
#   'Ram': '4GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '2.3kg',
#   'Price': 34578.72},
#  {'Unnamed: 0': 984,
#   'Company': 'Toshiba',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 6200U 2.3GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '1.75kg',
#   'Price': 48751.2},
#  {'Unnamed: 0': 985,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'AMD Radeon R5 M430',
#   'OpSys': 'Windows 10',
#   'Weight': '2.25kg',
#   'Price': 31914.72},
#  {'Unnamed: 0': 986,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '2.04kg',
#   'Price': 42943.68},
#  {'Unnamed: 0': 987,
#   'Company': 'Lenovo',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'IPS Panel Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1060',
#   'OpSys': 'Windows 10',
#   'Weight': '2.5kg',
#   'Price': 63349.92},
#  {'Unnamed: 0': 988,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '1TB HDD',
#   'Gpu': 'AMD Radeon R7 M445',
#   'OpSys': 'Windows 10',
#   'Weight': '2.36kg',
#   'Price': 39906.72},
#  {'Unnamed: 0': 989,
#   'Company': 'Dell',
#   'TypeName': 'Notebook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel HD Graphics 620 ',
#   'OpSys': 'Windows 10',
#   'Weight': '1.6kg',
#   'Price': 59620.32},
#  {'Unnamed: 0': 990,
#   'Company': 'HP',
#   'TypeName': 'Netbook',
#   'Inches': 12.5,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core M 6Y75 1.2GHz',
#   'Ram': '8GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel HD Graphics 515',
#   'OpSys': 'Windows 10',
#   'Weight': '0.97kg',
#   'Price': 101658.24},
#  {'Unnamed: 0': 991,
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i3 6006U 2GHz',
#   'Ram': '4GB',
#   'Memory': '128GB SSD +  1TB HDD',
#   'Gpu': 'AMD Radeon 520',
#   'OpSys': 'Windows 10',
#   'Weight': '2.1kg',
#   'Price': 26586.72},
#  {'Unnamed: 0': 992,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Celeron Dual Core N3350 1.1GHz',
#   'Ram': '4GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel HD Graphics 500',
#   'OpSys': 'No OS',
#   'Weight': '1.9kg',
#   'Price': 14418.6336},
#  {'Unnamed: 0': 993,
#   'Company': 'Lenovo',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 6200U 2.3GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 520',
#   'OpSys': 'Windows 10',
#   'Weight': '2.3kg',
#   'Price': 71874.72},
#  {'Unnamed: 0': 994,
#   'Company': 'Dell',
#   'TypeName': '2 in 1 Convertible',
#   'Inches': 13.3,
#   'ScreenResolution': 'Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.68kg',
#   'Price': 47365.92},
#  {'Unnamed: 0': 995,
#   'Company': 'Asus',
#   'TypeName': 'Notebook',
#   'Inches': 13.3,
#   'ScreenResolution': 'Quad HD+ 3200x1800',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.4kg',
#   'Price': 61272.0},
#  {'Unnamed: 0': 996,
#   'Company': 'HP',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.11kg',
#   'Price': 71874.72},
#  {'Unnamed: 0': 997,
#   'Company': 'Acer',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': '1366x768',
#   'Cpu': 'Intel Pentium Quad Core N4200 1.1GHz',
#   'Ram': '4GB',
#   'Memory': '500GB HDD',
#   'Gpu': 'Intel HD Graphics 505',
#   'OpSys': 'Windows 10',
#   'Weight': '2.4kg',
#   'Price': 20246.4},
#  {'Unnamed: 0': 998,
#   'Company': 'Asus',
#   'TypeName': 'Gaming',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7700HQ 2.8GHz',
#   'Ram': '16GB',
#   'Memory': '256GB SSD +  1TB HDD',
#   'Gpu': 'Nvidia GeForce GTX 1050 Ti',
#   'OpSys': 'Windows 10',
#   'Weight': '2.5kg',
#   'Price': 95850.72},
#  {'Unnamed: 0': 999,
#   'Company': 'HP',
#   'TypeName': 'Ultrabook',
#   'Inches': 14.0,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i7 7500U 2.7GHz',
#   'Ram': '8GB',
#   'Memory': '512GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'Windows 10',
#   'Weight': '1.48kg',
#   'Price': 111301.92},
#  ...]

# %% [markdown]
# ## steps to push the data into atlas collection
# ---
# 1. Create the database and cluster(create from atlas website)
# 2. Here create a database
# 3. Inside the database create a collection
# 4. push data into the collection

# %%
import os
CONNECTION_URL = os.getenv("mongo_connection_url")
DATABASE_NAME = "laptop_price"
COLLECTION_NAME = "laptop_price_collection"

# %%
# create the client for mongoDb
client = MongoClient(CONNECTION_URL)

# %%
# create the database
database = client[DATABASE_NAME]
# create the collection
collection = database[COLLECTION_NAME]

# %%
# now insert the data into the collection
records = collection.insert_many(data_dict)

# %%
records
# Out:
# InsertManyResult([ObjectId('68fbb014fdb7463efad71d08'), ObjectId('68fbb014fdb7463efad71d09'), ObjectId('68fbb014fdb7463efad71d0a'), ObjectId('68fbb014fdb7463efad71d0b'), ObjectId('68fbb014fdb7463efad71d0c'), ObjectId('68fbb014fdb7463efad71d0d'), ObjectId('68fbb014fdb7463efad71d0e'), ObjectId('68fbb014fdb7463efad71d0f'), ObjectId('68fbb014fdb7463efad71d10'), ObjectId('68fbb014fdb7463efad71d11'), ObjectId('68fbb014fdb7463efad71d12'), ObjectId('68fbb014fdb7463efad71d13'), ObjectId('68fbb014fdb7463efad71d14'), ObjectId('68fbb014fdb7463efad71d15'), ObjectId('68fbb014fdb7463efad71d16'), ObjectId('68fbb014fdb7463efad71d17'), ObjectId('68fbb014fdb7463efad71d18'), ObjectId('68fbb014fdb7463efad71d19'), ObjectId('68fbb014fdb7463efad71d1a'), ObjectId('68fbb014fdb7463efad71d1b'), ObjectId('68fbb014fdb7463efad71d1c'), ObjectId('68fbb014fdb7463efad71d1d'), ObjectId('68fbb014fdb7463efad71d1e'), ObjectId('68fbb014fdb7463efad71d1f'), ObjectId('68fbb014fdb7463efad71d20'), ObjectId('68fbb014fdb7463efad71d21'), ObjectId('68fbb014fdb7463efad71d22'), ObjectId('68fbb014fdb7463efad71d23'), ObjectId('68fbb014fdb7463efad71d24'), ObjectId('68fbb014fdb7463efad71d25'), ObjectId('68fbb014fdb7463efad71d26'), ObjectId('68fbb014fdb7463efad71d27'), ObjectId('68fbb014fdb7463efad71d28'), ObjectId('68fbb014fdb7463efad71d29'), ObjectId('68fbb014fdb7463efad71d2a'), ObjectId('68fbb014fdb7463efad71d2b'), ObjectId('68fbb014fdb7463efad71d2c'), ObjectId('68fbb014fdb7463efad71d2d'), ObjectId('68fbb014fdb7463efad71d2e'), ObjectId('68fbb014fdb7463efad71d2f'), ObjectId('68fbb014fdb7463efad71d30'), ObjectId('68fbb014fdb7463efad71d31'), ObjectId('68fbb014fdb7463efad71d32'), ObjectId('68fbb014fdb7463efad71d33'), ObjectId('68fbb014fdb7463efad71d34'), ObjectId('68fbb014fdb7463efad71d35'), ObjectId('68fbb014fdb7463efad71d36'), ObjectId('68fbb014fdb7463efad71d37'), ObjectId('68fbb014fdb7463efad71d38'), ObjectId('68fbb014fdb7463efad71d39'), ObjectId('68fbb014fdb7463efad71d3a'), ObjectId('68fbb014fdb7463efad71d3b'), ObjectId('68fbb014fdb7463efad71d3c'), ObjectId('68fbb014fdb7463efad71d3d'), ObjectId('68fbb014fdb7463efad71d3e'), ObjectId('68fbb014fdb7463efad71d3f'), ObjectId('68fbb014fdb7463efad71d40'), ObjectId('68fbb014fdb7463efad71d41'), ObjectId('68fbb014fdb7463efad71d42'), ObjectId('68fbb014fdb7463efad71d43'), ObjectId('68fbb014fdb7463efad71d44'), ObjectId('68fbb014fdb7463efad71d45'), ObjectId('68fbb014fdb7463efad71d46'), ObjectId('68fbb014fdb7463efad71d47'), ObjectId('68fbb014fdb7463efad71d48'), ObjectId('68fbb014fdb7463efad71d49'), ObjectId('68fbb014fdb7463efad71d4a'), ObjectId('68fbb014fdb7463efad71d4b'), ObjectId('68fbb014fdb7463efad71d4c'), ObjectId('68fbb014fdb7463efad71d4d'), ObjectId('68fbb014fdb7463efad71d4e'), ObjectId('68fbb014fdb7463efad71d4f'), ObjectId('68fbb014fdb7463efad71d50'), ObjectId('68fbb014fdb7463efad71d51'), ObjectId('68fbb014fdb7463efad71d52'), ObjectId('68fbb014fdb7463efad71d53'), ObjectId('68fbb014fdb7463efad71d54'), ObjectId('68fbb014fdb7463efad71d55'), ObjectId('68fbb014fdb7463efad71d56'), ObjectId('68fbb014fdb7463efad71d57'), ObjectId('68fbb014fdb7463efad71d58'), ObjectId('68fbb014fdb7463efad71d59'), ObjectId('68fbb014fdb7463efad71d5a'), ObjectId('68fbb014fdb7463efad71d5b'), ObjectId('68fbb014fdb7463efad71d5c'), ObjectId('68fbb014fdb7463efad71d5d'), ObjectId('68fbb014fdb7463efad71d5e'), ObjectId('68fbb014fdb7463efad71d5f'), ObjectId('68fbb014fdb7463efad71d60'), ObjectId('68fbb014fdb7463efad71d61'), ObjectId('68fbb014fdb7463efad71d62'), ObjectId('68fbb014fdb7463efad71d63'), ObjectId('68fbb014fdb7463efad71d64'), ObjectId('68fbb014fdb7463efad71d65'), ObjectId('68fbb014fdb7463efad71d66'), ObjectId('68fbb014fdb7463efad71d67'), ObjectId('68fbb014fdb7463efad71d68'), ObjectId('68fbb014fdb7463efad71d69'), ObjectId('68fbb014fdb7463efad71d6a'), ObjectId('68fbb014fdb7463efad71d6b'), ObjectId('68fbb014fdb7463efad71d6c'), ObjectId('68fbb014fdb7463efad71d6d'), ObjectId('68fbb014fdb7463efad71d6e'), ObjectId('68fbb014fdb7463efad71d6f'), ObjectId('68fbb014fdb7463efad7 ...

# %%
# get all the data from database
all_data = collection.find()

# %%
for i , j in enumerate(all_data):
    print(f"{i} : {j}")
# Out:
# 0 : {'_id': ObjectId('68fbb014fdb7463efad71d08'), 'Unnamed: 0': 0, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Retina Display 2560x1600', 'Cpu': 'Intel Core i5 2.3GHz', 'Ram': '8GB', 'Memory': '128GB SSD', 'Gpu': 'Intel Iris Plus Graphics 640', 'OpSys': 'macOS', 'Weight': '1.37kg', 'Price': 71378.6832}
# 1 : {'_id': ObjectId('68fbb014fdb7463efad71d09'), 'Unnamed: 0': 1, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': '1440x900', 'Cpu': 'Intel Core i5 1.8GHz', 'Ram': '8GB', 'Memory': '128GB Flash Storage', 'Gpu': 'Intel HD Graphics 6000', 'OpSys': 'macOS', 'Weight': '1.34kg', 'Price': 47895.5232}
# 2 : {'_id': ObjectId('68fbb014fdb7463efad71d0a'), 'Unnamed: 0': 2, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'No OS', 'Weight': '1.86kg', 'Price': 30636.0}
# 3 : {'_id': ObjectId('68fbb014fdb7463efad71d0b'), 'Unnamed: 0': 3, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 15.4, 'ScreenResolution': 'IPS Panel Retina Display 2880x1800', 'Cpu': 'Intel Core i7 2.7GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'AMD Radeon Pro 455', 'OpSys': 'macOS', 'Weight': '1.83kg', 'Price': 135195.33599999998}
# 4 : {'_id': ObjectId('68fbb014fdb7463efad71d0c'), 'Unnamed: 0': 4, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Retina Display 2560x1600', 'Cpu': 'Intel Core i5 3.1GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel Iris Plus Graphics 650', 'OpSys': 'macOS', 'Weight': '1.37kg', 'Price': 96095.808}
# 5 : {'_id': ObjectId('68fbb014fdb7463efad71d0d'), 'Unnamed: 0': 5, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'AMD A9-Series 9420 3GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'AMD Radeon R5', 'OpSys': 'Windows 10', 'Weight': '2.1kg', 'Price': 21312.0}
# 6 : {'_id': ObjectId('68fbb014fdb7463efad71d0e'), 'Unnamed: 0': 6, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 15.4, 'ScreenResolution': 'IPS Panel Retina Display 2880x1800', 'Cpu': 'Intel Core i7 2.2GHz', 'Ram': '16GB', 'Memory': '256GB Flash Storage', 'Gpu': 'Intel Iris Pro Graphics', 'OpSys': 'Mac OS X', 'Weight': '2.04kg', 'Price': 114017.6016}
# 7 : {'_id': ObjectId('68fbb014fdb7463efad71d0f'), 'Unnamed: 0': 7, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': '1440x900', 'Cpu': 'Intel Core i5 1.8GHz', 'Ram': '8GB', 'Memory': '256GB Flash Storage', 'Gpu': 'Intel HD Graphics 6000', 'OpSys': 'macOS', 'Weight': '1.34kg', 'Price': 61735.536}
# 8 : {'_id': ObjectId('68fbb014fdb7463efad71d10'), 'Unnamed: 0': 8, 'Company': 'Asus', 'TypeName': 'Ultrabook', 'Inches': 14.0, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'Nvidia GeForce MX150', 'OpSys': 'Windows 10', 'Weight': '1.3kg', 'Price': 79653.59999999999}
# 9 : {'_id': ObjectId('68fbb014fdb7463efad71d11'), 'Unnamed: 0': 9, 'Company': 'Acer', 'TypeName': 'Ultrabook', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.6kg', 'Price': 41025.6}
# 10 : {'_id': ObjectId('68fbb014fdb7463efad71d12'), 'Unnamed: 0': 10, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'No OS', 'Weight': '1.86kg', 'Price': 20986.992}
# 11 : {'_id': ObjectId('68fbb014fdb7463efad71d13'), 'Unnamed: 0': 11, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'No OS', 'Weight': '1.86kg', 'Price': 18381.0672}
# 12 : {'_id': ObjectId('68fbb014fdb7463efad71d14'), 'Unnamed: 0': 12, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 15.4, 'ScreenResolution': 'IPS Panel Retina Display 2880x1800', 'Cpu': 'Intel Core i7 2.8GHz', 'Ram': '16GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon Pro 555', 'OpSys': 'macOS', 'Weight': '1.83kg', 'Price': 130001.6016}
# 13 : {'_id': ObjectId('68fbb014fdb7463efad71d15'), 'Unnamed: 0': 13, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 26581.392}
# 14 : {'_id': ObjectId('68fbb014fdb7463efad71d16'), 'Unnamed: 0': 14, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 12.0, 'ScreenResolution': 'IPS Panel Retina Display 2304x1440', 'Cpu': 'Intel Core M m3 1.2GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 615', 'OpSys': 'macOS', 'Weight': '0.92kg', 'Price': 67260.672}
# 15 : {'_id': ObjectId('68fbb014fdb7463efad71d17'), 'Unnamed: 0': 15, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Retina Display 2560x1600', 'Cpu': 'Intel Core i5 2.3GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel Iris Plus Graphics 640', 'OpSys': 'macOS', 'Weight': '1.37kg', 'Price': 80908.344}
# 16 : {'_id': ObjectId('68fbb014fdb7463efad71d18'), 'Unnamed: 0': 16, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 39693.6}
# 17 : {'_id': ObjectId('68fbb014fdb7463efad71d19'), 'Unnamed: 0': 17, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 15.4, 'ScreenResolution': 'IPS Panel Retina Display 2880x1800', 'Cpu': 'Intel Core i7 2.9GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'AMD Radeon Pro 560', 'OpSys': 'macOS', 'Weight': '1.83kg', 'Price': 152274.24}
# 18 : {'_id': ObjectId('68fbb014fdb7463efad71d1a'), 'Unnamed: 0': 18, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 7100U 2.4GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce 940MX', 'OpSys': 'No OS', 'Weight': '2.2kg', 'Price': 26586.72}
# 19 : {'_id': ObjectId('68fbb014fdb7463efad71d1b'), 'Unnamed: 0': 19, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '128GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.22kg', 'Price': 52161.12}
# 20 : {'_id': ObjectId('68fbb014fdb7463efad71d1c'), 'Unnamed: 0': 20, 'Company': 'Asus', 'TypeName': 'Netbook', 'Inches': 11.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Atom x5-Z8350 1.44GHz', 'Ram': '2GB', 'Memory': '32GB Flash Storage', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Windows 10', 'Weight': '0.98kg', 'Price': 10224.432}
# 21 : {'_id': ObjectId('68fbb014fdb7463efad71d1d'), 'Unnamed: 0': 21, 'Company': 'Lenovo', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i5 7300HQ 2.5GHz', 'Ram': '8GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1050', 'OpSys': 'Windows 10', 'Weight': '2.5kg', 'Price': 53226.72}
# 22 : {'_id': ObjectId('68fbb014fdb7463efad71d1e'), 'Unnamed: 0': 22, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'AMD E-Series E2-9000e 1.5GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'AMD Radeon R2', 'OpSys': 'No OS', 'Weight': '1.86kg', 'Price': 13746.24}
# 23 : {'_id': ObjectId('68fbb014fdb7463efad71d1f'), 'Unnamed: 0': 23, 'Company': 'Dell', 'TypeName': '2 in 1 Convertible', 'Inches': 13.3, 'ScreenResolution': 'Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.62kg', 'Price': 43636.32}
# 24 : {'_id': ObjectId('68fbb014fdb7463efad71d20'), 'Unnamed: 0': 24, 'Company': 'HP', 'TypeName': 'Ultrabook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.91kg', 'Price': 35111.52}
# 25 : {'_id': ObjectId('68fbb014fdb7463efad71d21'), 'Unnamed: 0': 25, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '2.3kg', 'Price': 22305.1392}
# 26 : {'_id': ObjectId('68fbb014fdb7463efad71d22'), 'Unnamed: 0': 26, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': '1440x900', 'Cpu': 'Intel Core i5 1.6GHz', 'Ram': '8GB', 'Memory': '128GB Flash Storage', 'Gpu': 'Intel HD Graphics 6000', 'OpSys': 'Mac OS X', 'Weight': '1.35kg', 'Price': 58554.72}
# 27 : {'_id': ObjectId('68fbb014fdb7463efad71d23'), 'Unnamed: 0': 27, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon 530', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 42624.0}
# 28 : {'_id': ObjectId('68fbb014fdb7463efad71d24'), 'Unnamed: 0': 28, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8650U 1.9GHz', 'Ram': '8GB', 'Memory': '256GB SSD +  256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.88kg', 'Price': 69157.44}
# 29 : {'_id': ObjectId('68fbb014fdb7463efad71d25'), 'Unnamed: 0': 29, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce 930MX', 'OpSys': 'Windows 10', 'Weight': '2.5kg', 'Price': 47738.88}
# 30 : {'_id': ObjectId('68fbb014fdb7463efad71d26'), 'Unnamed: 0': 30, 'Company': 'Chuwi', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Atom x5-Z8300 1.44GHz', 'Ram': '4GB', 'Memory': '64GB Flash Storage', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '1.89kg', 'Price': 13053.0672}
# 31 : {'_id': ObjectId('68fbb014fdb7463efad71d27'), 'Unnamed: 0': 31, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': '1366x768', 'Cpu': 'AMD E-Series E2-6110 1.5GHz', 'Ram': '2GB', 'Memory': '32GB Flash Storage', 'Gpu': 'AMD Radeon R2', 'OpSys': 'Windows 10', 'Weight': '1.65kg', 'Price': 10602.72}
# 32 : {'_id': ObjectId('68fbb014fdb7463efad71d28'), 'Unnamed: 0': 32, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD A6-Series 9220 2.5GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'AMD Radeon 530', 'OpSys': 'Windows 10', 'Weight': '2.71kg', 'Price': 23389.92}
# 33 : {'_id': ObjectId('68fbb014fdb7463efad71d29'), 'Unnamed: 0': 33, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'Touchscreen / Quad HD+ 3200x1800', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.2kg', 'Price': 99580.32}
# 34 : {'_id': ObjectId('68fbb014fdb7463efad71d2a'), 'Unnamed: 0': 34, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': '1440x900', 'Cpu': 'Intel Core i5 1.6GHz', 'Ram': '8GB', 'Memory': '256GB Flash Storage', 'Gpu': 'Intel HD Graphics 6000', 'OpSys': 'Mac OS X', 'Weight': '1.35kg', 'Price': 53173.44}
# 35 : {'_id': ObjectId('68fbb014fdb7463efad71d2b'), 'Unnamed: 0': 35, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3350 1.1GHz', 'Ram': '4GB', 'Memory': '64GB Flash Storage', 'Gpu': 'Intel HD Graphics 500', 'OpSys': 'Windows 10', 'Weight': '1.44kg', 'Price': 13266.72}
# 36 : {'_id': ObjectId('68fbb014fdb7463efad71d2c'), 'Unnamed: 0': 36, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 7130U 2.7GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Linux', 'Weight': '2.1kg', 'Price': 19553.76}
# 37 : {'_id': ObjectId('68fbb014fdb7463efad71d2d'), 'Unnamed: 0': 37, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'AMD Radeon 530', 'OpSys': 'Windows 10', 'Weight': '2.8kg', 'Price': 52161.12}
# 38 : {'_id': ObjectId('68fbb014fdb7463efad71d2e'), 'Unnamed: 0': 38, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.86kg', 'Price': 26037.4032}
# 39 : {'_id': ObjectId('68fbb014fdb7463efad71d2f'), 'Unnamed: 0': 39, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce 930MX ', 'OpSys': 'Windows 10', 'Weight': '2.1kg', 'Price': 46833.12}
# 40 : {'_id': ObjectId('68fbb014fdb7463efad71d30'), 'Unnamed: 0': 40, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Linux', 'Weight': '2kg', 'Price': 20725.92}
# 41 : {'_id': ObjectId('68fbb014fdb7463efad71d31'), 'Unnamed: 0': 41, 'Company': 'Dell', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '16GB', 'Memory': '256GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1060', 'OpSys': 'Windows 10', 'Weight': '2.65kg', 'Price': 79866.72}
# 42 : {'_id': ObjectId('68fbb014fdb7463efad71d32'), 'Unnamed: 0': 42, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce 940MX', 'OpSys': 'Linux', 'Weight': '2.3kg', 'Price': 27864.9072}
# 43 : {'_id': ObjectId('68fbb014fdb7463efad71d33'), 'Unnamed: 0': 43, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 36336.96}
# 44 : {'_id': ObjectId('68fbb014fdb7463efad71d34'), 'Unnamed: 0': 44, 'Company': 'Dell', 'TypeName': '2 in 1 Convertible', 'Inches': 17.3, 'ScreenResolution': 'Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '12GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce 150MX', 'OpSys': 'Windows 10', 'Weight': '2.77kg', 'Price': 53226.72}
# 45 : {'_id': ObjectId('68fbb014fdb7463efad71d35'), 'Unnamed: 0': 45, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Retina Display 2560x1600', 'Cpu': 'Intel Core i5 2.0GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel Iris Graphics 540', 'OpSys': 'macOS', 'Weight': '1.37kg', 'Price': 75604.31999999999}
# 46 : {'_id': ObjectId('68fbb014fdb7463efad71d36'), 'Unnamed: 0': 46, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '128GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'No OS', 'Weight': '2.2kg', 'Price': 19660.32}
# 47 : {'_id': ObjectId('68fbb014fdb7463efad71d37'), 'Unnamed: 0': 47, 'Company': 'Asus', 'TypeName': 'Gaming', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD Ryzen 1700 3GHz', 'Ram': '8GB', 'Memory': '256GB SSD +  1TB HDD', 'Gpu': 'AMD Radeon RX 580', 'OpSys': 'Windows 10', 'Weight': '3.2kg', 'Price': 69210.72}
# 48 : {'_id': ObjectId('68fbb014fdb7463efad71d38'), 'Unnamed: 0': 48, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Windows 10', 'Weight': '2.3kg', 'Price': 34045.92}
# 49 : {'_id': ObjectId('68fbb014fdb7463efad71d39'), 'Unnamed: 0': 49, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Pentium Quad Core N4200 1.1GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce 920MX', 'OpSys': 'Windows 10', 'Weight': '2.8kg', 'Price': 24828.48}
# 50 : {'_id': ObjectId('68fbb014fdb7463efad71d3a'), 'Unnamed: 0': 50, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 10.1, 'ScreenResolution': 'IPS Panel Touchscreen 1920x1200', 'Cpu': 'Intel Atom x5-Z8550 1.44GHz', 'Ram': '4GB', 'Memory': '64GB Flash Storage', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Android', 'Weight': '0.69kg', 'Price': 16996.32}
# 51 : {'_id': ObjectId('68fbb014fdb7463efad71d3b'), 'Unnamed: 0': 51, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce MX150', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 44808.48}
# 52 : {'_id': ObjectId('68fbb014fdb7463efad71d3c'), 'Unnamed: 0': 52, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD A6-Series 9220 2.5GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon R4 Graphics', 'OpSys': 'Windows 10', 'Weight': '1.86kg', 'Price': 21231.5472}
# 53 : {'_id': ObjectId('68fbb014fdb7463efad71d3d'), 'Unnamed: 0': 53, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 13.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '512GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.49kg', 'Price': 58767.84}
# 54 : {'_id': ObjectId('68fbb014fdb7463efad71d3e'), 'Unnamed: 0': 54, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 7100U 2.4GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.4kg', 'Price': 20459.52}
# 55 : {'_id': ObjectId('68fbb014fdb7463efad71d3f'), 'Unnamed: 0': 55, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon 520', 'OpSys': 'Windows 10', 'Weight': '2.13kg', 'Price': 40908.384}
# 56 : {'_id': ObjectId('68fbb014fdb7463efad71d40'), 'Unnamed: 0': 56, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '128GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.91kg', 'Price': 23389.92}
# 57 : {'_id': ObjectId('68fbb014fdb7463efad71d41'), 'Unnamed: 0': 57, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2kg', 'Price': 31232.203200000004}
# 58 : {'_id': ObjectId('68fbb014fdb7463efad71d42'), 'Unnamed: 0': 58, 'Company': 'MSI', 'TypeName': 'Gaming', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '16GB', 'Memory': '256GB SSD +  2TB HDD', 'Gpu': 'Nvidia GeForce GTX 1070', 'OpSys': 'Windows 10', 'Weight': '2.43kg', 'Price': 130482.72}
# 59 : {'_id': ObjectId('68fbb014fdb7463efad71d43'), 'Unnamed: 0': 59, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Linux', 'Weight': '2kg', 'Price': 22111.2}
# 60 : {'_id': ObjectId('68fbb014fdb7463efad71d44'), 'Unnamed: 0': 60, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '16GB', 'Memory': '256GB SSD +  2TB HDD', 'Gpu': 'AMD Radeon 530', 'OpSys': 'Windows 10', 'Weight': '2.8kg', 'Price': 69210.72}
# 61 : {'_id': ObjectId('68fbb014fdb7463efad71d45'), 'Unnamed: 0': 61, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 14.0, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.7kg', 'Price': 46833.12}
# 62 : {'_id': ObjectId('68fbb014fdb7463efad71d46'), 'Unnamed: 0': 62, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i3 7130U 2.7GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'No OS', 'Weight': '1.7kg', 'Price': 31914.72}
# 63 : {'_id': ObjectId('68fbb014fdb7463efad71d47'), 'Unnamed: 0': 63, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.4kg', 'Price': 50136.48}
# 64 : {'_id': ObjectId('68fbb014fdb7463efad71d48'), 'Unnamed: 0': 64, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.86kg', 'Price': 36763.2}
# 65 : {'_id': ObjectId('68fbb014fdb7463efad71d49'), 'Unnamed: 0': 65, 'Company': 'Asus', 'TypeName': 'Ultrabook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'Nvidia GeForce GTX 1050 Ti', 'OpSys': 'Windows 10', 'Weight': '1.8kg', 'Price': 105654.24}
# 66 : {'_id': ObjectId('68fbb014fdb7463efad71d4a'), 'Unnamed: 0': 66, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'AMD Radeon 520', 'OpSys': 'Windows 10', 'Weight': '1.86kg', 'Price': 23373.4032}
# 67 : {'_id': ObjectId('68fbb014fdb7463efad71d4b'), 'Unnamed: 0': 67, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz', 'Ram': '4GB', 'Memory': '32GB SSD', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Windows 10', 'Weight': '1.44kg', 'Price': 12201.12}
# 68 : {'_id': ObjectId('68fbb014fdb7463efad71d4c'), 'Unnamed: 0': 68, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.9kg', 'Price': 29250.72}
# 69 : {'_id': ObjectId('68fbb014fdb7463efad71d4d'), 'Unnamed: 0': 69, 'Company': 'Asus', 'TypeName': 'Gaming', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '12GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1050 Ti', 'OpSys': 'Linux', 'Weight': '3kg', 'Price': 50562.72}
# 70 : {'_id': ObjectId('68fbb014fdb7463efad71d4e'), 'Unnamed: 0': 70, 'Company': 'Microsoft', 'TypeName': 'Ultrabook', 'Inches': 13.5, 'ScreenResolution': 'Touchscreen 2256x1504', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '4GB', 'Memory': '128GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10 S', 'Weight': '1.252kg', 'Price': 58021.92}
# 71 : {'_id': ObjectId('68fbb014fdb7463efad71d4f'), 'Unnamed: 0': 71, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon 530', 'OpSys': 'Windows 10', 'Weight': '1.4kg', 'Price': 50882.4}
# 72 : {'_id': ObjectId('68fbb014fdb7463efad71d50'), 'Unnamed: 0': 72, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon 530', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 46353.6}
# 73 : {'_id': ObjectId('68fbb014fdb7463efad71d51'), 'Unnamed: 0': 73, 'Company': 'MSI', 'TypeName': 'Gaming', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7300HQ 2.5GHz', 'Ram': '8GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1050', 'OpSys': 'Windows 10', 'Weight': '2.7kg', 'Price': 58341.6}
# 74 : {'_id': ObjectId('68fbb014fdb7463efad71d52'), 'Unnamed: 0': 74, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '2.1kg', 'Price': 20725.92}
# 75 : {'_id': ObjectId('68fbb014fdb7463efad71d53'), 'Unnamed: 0': 75, 'Company': 'Asus', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1050', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 50562.72}
# 76 : {'_id': ObjectId('68fbb014fdb7463efad71d54'), 'Unnamed: 0': 76, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '2TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'No OS', 'Weight': '2.2kg', 'Price': 27652.32}
# 77 : {'_id': ObjectId('68fbb014fdb7463efad71d55'), 'Unnamed: 0': 77, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.02kg', 'Price': 45554.4}
# 78 : {'_id': ObjectId('68fbb014fdb7463efad71d56'), 'Unnamed: 0': 78, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 7130U 2.7GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce MX130', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 28238.4}
# 79 : {'_id': ObjectId('68fbb014fdb7463efad71d57'), 'Unnamed: 0': 79, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce 930MX', 'OpSys': 'Windows 10', 'Weight': '2.5kg', 'Price': 52054.56}
# 80 : {'_id': ObjectId('68fbb014fdb7463efad71d58'), 'Unnamed: 0': 80, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.88kg', 'Price': 58403.4048}
# 81 : {'_id': ObjectId('68fbb014fdb7463efad71d59'), 'Unnamed: 0': 81, 'Company': 'Apple', 'TypeName': 'Ultrabook', 'Inches': 12.0, 'ScreenResolution': 'IPS Panel Retina Display 2304x1440', 'Cpu': 'Intel Core i5 1.3GHz', 'Ram': '8GB', 'Memory': '512GB SSD', 'Gpu': 'Intel HD Graphics 615', 'OpSys': 'macOS', 'Weight': '0.92kg', 'Price': 80452.8}
# 82 : {'_id': ObjectId('68fbb014fdb7463efad71d5a'), 'Unnamed: 0': 82, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.63kg', 'Price': 45820.8}
# 83 : {'_id': ObjectId('68fbb014fdb7463efad71d5b'), 'Unnamed: 0': 83, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD A6-Series 9220 2.5GHz', 'Ram': '4GB', 'Memory': '128GB SSD', 'Gpu': 'AMD R4 Graphics', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 21258.72}
# 84 : {'_id': ObjectId('68fbb014fdb7463efad71d5c'), 'Unnamed: 0': 84, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'AMD A9-Series 9420 3GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5', 'OpSys': 'Windows 10', 'Weight': '2.1kg', 'Price': 21045.6}
# 85 : {'_id': ObjectId('68fbb014fdb7463efad71d5d'), 'Unnamed: 0': 85, 'Company': 'Dell', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '16GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1050 Ti', 'OpSys': 'Windows 10', 'Weight': '2.65kg', 'Price': 71874.72}
# 86 : {'_id': ObjectId('68fbb014fdb7463efad71d5e'), 'Unnamed: 0': 86, 'Company': 'HP', 'TypeName': 'Ultrabook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce GTX 940MX', 'OpSys': 'Windows 10', 'Weight': '1.83kg', 'Price': 37242.72}
# 87 : {'_id': ObjectId('68fbb014fdb7463efad71d5f'), 'Unnamed: 0': 87, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.96kg', 'Price': 31914.1872}
# 88 : {'_id': ObjectId('68fbb014fdb7463efad71d60'), 'Unnamed: 0': 88, 'Company': 'Asus', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '16GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1060', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 77202.72}
# 89 : {'_id': ObjectId('68fbb014fdb7463efad71d61'), 'Unnamed: 0': 89, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.21kg', 'Price': 87858.72}
# 90 : {'_id': ObjectId('68fbb014fdb7463efad71d62'), 'Unnamed: 0': 90, 'Company': 'Asus', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD FX 9830P 3GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon RX 560', 'OpSys': 'Windows 10', 'Weight': '2.45kg', 'Price': 37242.72}
# 91 : {'_id': ObjectId('68fbb014fdb7463efad71d63'), 'Unnamed: 0': 91, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce MX150', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 36709.92}
# 92 : {'_id': ObjectId('68fbb014fdb7463efad71d64'), 'Unnamed: 0': 92, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 13.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.49kg', 'Price': 63776.16}
# 93 : {'_id': ObjectId('68fbb014fdb7463efad71d65'), 'Unnamed: 0': 93, 'Company': 'Dell', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7300HQ 2.5GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce GTX 1060', 'OpSys': 'Windows 10', 'Weight': '2.65kg', 'Price': 63669.6}
# 94 : {'_id': ObjectId('68fbb014fdb7463efad71d66'), 'Unnamed: 0': 94, 'Company': 'Asus', 'TypeName': 'Ultrabook', 'Inches': 14.0, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.25kg', 'Price': 55890.72}
# 95 : {'_id': ObjectId('68fbb014fdb7463efad71d67'), 'Unnamed: 0': 95, 'Company': 'Acer', 'TypeName': '2 in 1 Convertible', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.5kg', 'Price': 45128.16}
# 96 : {'_id': ObjectId('68fbb014fdb7463efad71d68'), 'Unnamed: 0': 96, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Linux', 'Weight': '2.2kg', 'Price': 31962.672}
# 97 : {'_id': ObjectId('68fbb014fdb7463efad71d69'), 'Unnamed: 0': 97, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Linux', 'Weight': '2.2kg', 'Price': 25840.8}
# 98 : {'_id': ObjectId('68fbb014fdb7463efad71d6a'), 'Unnamed: 0': 98, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 7100U 2.4GHz', 'Ram': '6GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce 920M', 'OpSys': 'Windows 10', 'Weight': '2kg', 'Price': 30742.56}
# 99 : {'_id': ObjectId('68fbb014fdb7463efad71d6b'), 'Unnamed: 0': 99, 'Company': 'HP', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '12GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1050', 'OpSys': 'Windows 10', 'Weight': '2.62kg', 'Price': 66546.72}
# 100 : {'_id': ObjectId('68fbb014fdb7463efad71d6c'), 'Unnamed: 0': 100, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon 530', 'OpSys': 'Windows 10', 'Weight': '1.91kg', 'Price': 38308.32}
# 101 : {'_id': ObjectId('68fbb014fdb7463efad71d6d'), 'Unnamed: 0': 101, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD E-Series E2-9000e 1.5GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'AMD Radeon R2', 'OpSys': 'Windows 10', 'Weight': '2.1kg', 'Price': 18594.72}
# 102 : {'_id': ObjectId('68fbb014fdb7463efad71d6e'), 'Unnamed: 0': 102, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon 520', 'OpSys': 'Linux', 'Weight': '2.2kg', 'Price': 34472.16}
# 103 : {'_id': ObjectId('68fbb014fdb7463efad71d6f'), 'Unnamed: 0': 103, 'Company': 'HP', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce MX150', 'OpSys': 'Windows 10', 'Weight': '1.38kg', 'Price': 59620.32}
# 104 : {'_id': ObjectId('68fbb014fdb7463efad71d70'), 'Unnamed: 0': 104, 'Company': 'Microsoft', 'TypeName': 'Ultrabook', 'Inches': 13.5, 'ScreenResolution': 'Touchscreen 2256x1504', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10 S', 'Weight': '1.252kg', 'Price': 71395.2}
# 105 : {'_id': ObjectId('68fbb014fdb7463efad71d71'), 'Unnamed: 0': 105, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '6GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce 940MX', 'OpSys': 'Windows 10', 'Weight': '1.58kg', 'Price': 35111.52}
# 106 : {'_id': ObjectId('68fbb014fdb7463efad71d72'), 'Unnamed: 0': 106, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.85kg', 'Price': 22105.872}
# 107 : {'_id': ObjectId('68fbb014fdb7463efad71d73'), 'Unnamed: 0': 107, 'Company': 'Asus', 'TypeName': 'Ultrabook', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce 940MX', 'OpSys': 'Windows 10', 'Weight': '1.3kg', 'Price': 63563.04}
# 108 : {'_id': ObjectId('68fbb014fdb7463efad71d74'), 'Unnamed: 0': 108, 'Company': 'MSI', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '16GB', 'Memory': '256GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1050 Ti', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 69210.72}
# 109 : {'_id': ObjectId('68fbb014fdb7463efad71d75'), 'Unnamed: 0': 109, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.58kg', 'Price': 78854.4}
# 110 : {'_id': ObjectId('68fbb014fdb7463efad71d76'), 'Unnamed: 0': 110, 'Company': 'Asus', 'TypeName': 'Ultrabook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '16GB', 'Memory': '256GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce MX150', 'OpSys': 'Windows 10', 'Weight': '1.5kg', 'Price': 67239.36}
# 111 : {'_id': ObjectId('68fbb014fdb7463efad71d77'), 'Unnamed: 0': 111, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'Quad HD+ / Touchscreen 3200x1800', 'Cpu': 'Intel Core i7 7560U 2.4GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel Iris Plus Graphics 640', 'OpSys': 'Windows 10', 'Weight': '1.23kg', 'Price': 73473.12}
# 112 : {'_id': ObjectId('68fbb014fdb7463efad71d78'), 'Unnamed: 0': 112, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.37kg', 'Price': 74538.72}
# 113 : {'_id': ObjectId('68fbb014fdb7463efad71d79'), 'Unnamed: 0': 113, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel 1366x768', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.63kg', 'Price': 38468.16}
# 114 : {'_id': ObjectId('68fbb014fdb7463efad71d7a'), 'Unnamed: 0': 114, 'Company': 'Dell', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.21kg', 'Price': 86793.12}
# 115 : {'_id': ObjectId('68fbb014fdb7463efad71d7b'), 'Unnamed: 0': 115, 'Company': 'HP', 'TypeName': '2 in 1 Convertible', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.26kg', 'Price': 74538.1872}
# 116 : {'_id': ObjectId('68fbb014fdb7463efad71d7c'), 'Unnamed: 0': 116, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '512GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.63kg', 'Price': 57755.52}
# 117 : {'_id': ObjectId('68fbb014fdb7463efad71d7d'), 'Unnamed: 0': 117, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce 940MX', 'OpSys': 'Windows 10', 'Weight': '2.16kg', 'Price': 60223.98239999999}
# 118 : {'_id': ObjectId('68fbb014fdb7463efad71d7e'), 'Unnamed: 0': 118, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce 920MX', 'OpSys': 'Windows 10', 'Weight': '2kg', 'Price': 30049.92}
# 119 : {'_id': ObjectId('68fbb014fdb7463efad71d7f'), 'Unnamed: 0': 119, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce 940MX', 'OpSys': 'Windows 10', 'Weight': '1.7kg', 'Price': 59567.04}
# 120 : {'_id': ObjectId('68fbb014fdb7463efad71d80'), 'Unnamed: 0': 120, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i3 7100U 2.4GHz', 'Ram': '6GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.1kg', 'Price': 25521.12}
# 121 : {'_id': ObjectId('68fbb014fdb7463efad71d81'), 'Unnamed: 0': 121, 'Company': 'MSI', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 7700HQ 2.8GHz', 'Ram': '16GB', 'Memory': '256GB SSD +  2TB HDD', 'Gpu': 'Nvidia GeForce GTX 1070', 'OpSys': 'Windows 10', 'Weight': '1.8kg', 'Price': 119427.12}
# 122 : {'_id': ObjectId('68fbb014fdb7463efad71d82'), 'Unnamed: 0': 122, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce 940MX', 'OpSys': 'No OS', 'Weight': '2.2kg', 'Price': 33513.119999999995}
# 123 : {'_id': ObjectId('68fbb014fdb7463efad71d83'), 'Unnamed: 0': 123, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'Nvidia GeForce 930MX ', 'OpSys': 'Windows 10', 'Weight': '2.5kg', 'Price': 67718.88}
# 124 : {'_id': ObjectId('68fbb014fdb7463efad71d84'), 'Unnamed: 0': 124, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'AMD A9-Series 9420 3GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'AMD Radeon R5', 'OpSys': 'Windows 10', 'Weight': '2.1kg', 'Price': 24029.28}
# 125 : {'_id': ObjectId('68fbb014fdb7463efad71d85'), 'Unnamed: 0': 125, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'No OS', 'Weight': '1.86kg', 'Price': 13799.52}
# 126 : {'_id': ObjectId('68fbb014fdb7463efad71d86'), 'Unnamed: 0': 126, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.63kg', 'Price': 43263.36}
# 127 : {'_id': ObjectId('68fbb014fdb7463efad71d87'), 'Unnamed: 0': 127, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': '1366x768', 'Cpu': 'AMD E-Series 6110 1.5GHz', 'Ram': '4GB', 'Memory': '64GB SSD', 'Gpu': 'AMD Radeon R2', 'OpSys': 'Windows 10 S', 'Weight': '1.65kg', 'Price': 14811.3072}
# 128 : {'_id': ObjectId('68fbb014fdb7463efad71d88'), 'Unnamed: 0': 128, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '16GB', 'Memory': '256GB SSD +  2TB HDD', 'Gpu': 'AMD Radeon 530', 'OpSys': 'Windows 10', 'Weight': '2.8kg', 'Price': 74378.87999999999}
# 129 : {'_id': ObjectId('68fbb014fdb7463efad71d89'), 'Unnamed: 0': 129, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 8250U 1.6GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.5kg', 'Price': 49443.84}
# 130 : {'_id': ObjectId('68fbb014fdb7463efad71d8a'), 'Unnamed: 0': 130, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R7 M445', 'OpSys': 'Windows 10', 'Weight': '2.36kg', 'Price': 34045.3872}
# 131 : {'_id': ObjectId('68fbb014fdb7463efad71d8b'), 'Unnamed: 0': 131, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 23922.72}
# 132 : {'_id': ObjectId('68fbb014fdb7463efad71d8c'), 'Unnamed: 0': 132, 'Company': 'Acer', 'TypeName': 'Ultrabook', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.6kg', 'Price': 47099.52}
# 133 : {'_id': ObjectId('68fbb014fdb7463efad71d8d'), 'Unnamed: 0': 133, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i3 7130U 2.7GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'Nvidia GeForce MX130', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 30476.16}
# 134 : {'_id': ObjectId('68fbb014fdb7463efad71d8e'), 'Unnamed: 0': 134, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.05kg', 'Price': 31861.44}
# 135 : {'_id': ObjectId('68fbb014fdb7463efad71d8f'), 'Unnamed: 0': 135, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 8550U 1.8GHz', 'Ram': '8GB', 'Memory': '256GB SSD', 'Gpu': 'Intel UHD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.63kg', 'Price': 52640.64}
# 136 : {'_id': ObjectId('68fbb014fdb7463efad71d90'), 'Unnamed: 0': 136, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3350 1.1GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 500', 'OpSys': 'No OS', 'Weight': '1.9kg', 'Price': 13445.7408}
# 137 : {'_id': ObjectId('68fbb014fdb7463efad71d91'), 'Unnamed: 0': 137, 'Company': 'Asus', 'TypeName': 'Gaming', 'Inches': 17.3, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7300HQ 2.5GHz', 'Ram': '8GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 1050', 'OpSys': 'Windows 10', 'Weight': '3kg', 'Price': 49976.64}
# 138 : {'_id': ObjectId('68fbb014fdb7463efad71d92'), 'Unnamed: 0': 138, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce 920MX', 'OpSys': 'No OS', 'Weight': '2.2kg', 'Price': 26586.72}
# 139 : {'_id': ObjectId('68fbb014fdb7463efad71d93'), 'Unnamed: 0': 139, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i5 7200U 2.5GHz', 'Ram': '4GB', 'Memory': '256GB SSD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '1.32kg', 'Price': 37242.72}
# 140 : {'_id': ObjectId('68fbb014fdb7463efad71d94'), 'Unnamed: 0': 140, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 17.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i3 7130U 2.7GHz', 'Ram': '4GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce MX130', 'OpSys': 'Windows 10', 'Weight': '3kg', 'Price': 34898.4}
# ...
# 1257 : {'_id': ObjectId('68fbb014fdb7463efad721f1'), 'Unnamed: 0': 1257, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 6006U 2GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '2.29kg', 'Price': 26107.2}
# 1258 : {'_id': ObjectId('68fbb014fdb7463efad721f2'), 'Unnamed: 0': 1258, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '8GB', 'Memory': '1.0TB Hybrid', 'Gpu': 'AMD Radeon R5 M330', 'OpSys': 'Windows 7', 'Weight': '2.32kg', 'Price': 47685.6}
# 1259 : {'_id': ObjectId('68fbb014fdb7463efad721f3'), 'Unnamed: 0': 1259, 'Company': 'MSI', 'TypeName': 'Gaming', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'Intel Core i7 6700HQ 2.6GHz', 'Ram': '8GB', 'Memory': '128GB SSD +  1TB HDD', 'Gpu': 'Nvidia GeForce GTX 960M', 'OpSys': 'Windows 10', 'Weight': '2.4kg', 'Price': 65481.12}
# 1260 : {'_id': ObjectId('68fbb014fdb7463efad721f4'), 'Unnamed: 0': 1260, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 14.0, 'ScreenResolution': 'Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i5 6200U 2.3GHz', 'Ram': '4GB', 'Memory': '128GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.8kg', 'Price': 44382.7728}
# 1261 : {'_id': ObjectId('68fbb014fdb7463efad721f5'), 'Unnamed: 0': 1261, 'Company': 'Asus', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core M 6Y30 0.9GHz', 'Ram': '8GB', 'Memory': '512GB SSD', 'Gpu': 'Intel HD Graphics 515', 'OpSys': 'Windows 10', 'Weight': '1.2kg', 'Price': 38841.12}
# 1262 : {'_id': ObjectId('68fbb014fdb7463efad721f6'), 'Unnamed: 0': 1262, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 7100U 2.4GHz', 'Ram': '6GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.3kg', 'Price': 24455.52}
# 1263 : {'_id': ObjectId('68fbb014fdb7463efad721f7'), 'Unnamed: 0': 1263, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Linux', 'Weight': '2.4kg', 'Price': 15397.92}
# 1264 : {'_id': ObjectId('68fbb014fdb7463efad721f8'), 'Unnamed: 0': 1264, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '2GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '2.20kg', 'Price': 20193.12}
# 1265 : {'_id': ObjectId('68fbb014fdb7463efad721f9'), 'Unnamed: 0': 1265, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 6700HQ 2.6GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce GTX 960M', 'OpSys': 'Windows 10', 'Weight': '2.6kg', 'Price': 47898.72}
# 1266 : {'_id': ObjectId('68fbb014fdb7463efad721fa'), 'Unnamed: 0': 1266, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD A9-Series 9410 2.9GHz', 'Ram': '6GB', 'Memory': '1.0TB Hybrid', 'Gpu': 'AMD Radeon R7 M440', 'OpSys': 'Windows 10', 'Weight': '2.04kg', 'Price': 29303.4672}
# 1267 : {'_id': ObjectId('68fbb014fdb7463efad721fb'), 'Unnamed: 0': 1267, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Linux', 'Weight': '2.3kg', 'Price': 42943.1472}
# 1268 : {'_id': ObjectId('68fbb014fdb7463efad721fc'), 'Unnamed: 0': 1268, 'Company': 'HP', 'TypeName': 'Netbook', 'Inches': 11.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz', 'Ram': '2GB', 'Memory': '32GB Flash Storage', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Windows 10', 'Weight': '1.17kg', 'Price': 11135.52}
# 1269 : {'_id': ObjectId('68fbb014fdb7463efad721fd'), 'Unnamed: 0': 1269, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Nvidia GeForce 920M', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 38378.6496}
# 1270 : {'_id': ObjectId('68fbb014fdb7463efad721fe'), 'Unnamed: 0': 1270, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '4GB', 'Memory': '128GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.8kg', 'Price': 33992.64}
# 1271 : {'_id': ObjectId('68fbb014fdb7463efad721ff'), 'Unnamed: 0': 1271, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Quad HD+ / Touchscreen 3200x1800', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.3kg', 'Price': 79866.72}
# 1272 : {'_id': ObjectId('68fbb014fdb7463efad72200'), 'Unnamed: 0': 1272, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '2GB', 'Memory': '64GB Flash Storage', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '1.5kg', 'Price': 12201.12}
# 1273 : {'_id': ObjectId('68fbb014fdb7463efad72201'), 'Unnamed: 0': 1273, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '6GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5 M330', 'OpSys': 'Windows 10', 'Weight': '2.19kg', 'Price': 40705.92}
# 1274 : {'_id': ObjectId('68fbb014fdb7463efad72202'), 'Unnamed: 0': 1274, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 19660.32}
# 1275 : {'_id': ObjectId('68fbb014fdb7463efad72203'), 'Unnamed: 0': 1275, 'Company': 'Asus', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core M 6Y30 0.9GHz', 'Ram': '8GB', 'Memory': '512GB SSD', 'Gpu': 'Intel HD Graphics 515', 'OpSys': 'Windows 10', 'Weight': '1.2kg', 'Price': 38841.12}
# 1276 : {'_id': ObjectId('68fbb014fdb7463efad72204'), 'Unnamed: 0': 1276, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 7100U 2.4GHz', 'Ram': '6GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.3kg', 'Price': 24455.52}
# 1277 : {'_id': ObjectId('68fbb014fdb7463efad72205'), 'Unnamed: 0': 1277, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Linux', 'Weight': '2.4kg', 'Price': 15397.92}
# 1278 : {'_id': ObjectId('68fbb014fdb7463efad72206'), 'Unnamed: 0': 1278, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '2GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '2.20kg', 'Price': 20193.12}
# 1279 : {'_id': ObjectId('68fbb014fdb7463efad72207'), 'Unnamed: 0': 1279, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 6700HQ 2.6GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce GTX 960M', 'OpSys': 'Windows 10', 'Weight': '2.6kg', 'Price': 47898.72}
# 1280 : {'_id': ObjectId('68fbb014fdb7463efad72208'), 'Unnamed: 0': 1280, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD A9-Series 9410 2.9GHz', 'Ram': '6GB', 'Memory': '1.0TB Hybrid', 'Gpu': 'AMD Radeon R7 M440', 'OpSys': 'Windows 10', 'Weight': '2.04kg', 'Price': 29303.4672}
# 1281 : {'_id': ObjectId('68fbb014fdb7463efad72209'), 'Unnamed: 0': 1281, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Linux', 'Weight': '2.3kg', 'Price': 42943.1472}
# 1282 : {'_id': ObjectId('68fbb014fdb7463efad7220a'), 'Unnamed: 0': 1282, 'Company': 'HP', 'TypeName': 'Netbook', 'Inches': 11.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz', 'Ram': '2GB', 'Memory': '32GB Flash Storage', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Windows 10', 'Weight': '1.17kg', 'Price': 11135.52}
# 1283 : {'_id': ObjectId('68fbb014fdb7463efad7220b'), 'Unnamed: 0': 1283, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Nvidia GeForce 920M', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 38378.6496}
# 1284 : {'_id': ObjectId('68fbb014fdb7463efad7220c'), 'Unnamed: 0': 1284, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '4GB', 'Memory': '128GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.8kg', 'Price': 33992.64}
# 1285 : {'_id': ObjectId('68fbb014fdb7463efad7220d'), 'Unnamed: 0': 1285, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Quad HD+ / Touchscreen 3200x1800', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.3kg', 'Price': 79866.72}
# 1286 : {'_id': ObjectId('68fbb014fdb7463efad7220e'), 'Unnamed: 0': 1286, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '2GB', 'Memory': '64GB Flash Storage', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '1.5kg', 'Price': 12201.12}
# 1287 : {'_id': ObjectId('68fbb014fdb7463efad7220f'), 'Unnamed: 0': 1287, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '6GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5 M330', 'OpSys': 'Windows 10', 'Weight': '2.19kg', 'Price': 40705.92}
# 1288 : {'_id': ObjectId('68fbb014fdb7463efad72210'), 'Unnamed: 0': 1288, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 19660.32}
# 1289 : {'_id': ObjectId('68fbb014fdb7463efad72211'), 'Unnamed: 0': 1289, 'Company': 'Asus', 'TypeName': 'Ultrabook', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core M 6Y30 0.9GHz', 'Ram': '8GB', 'Memory': '512GB SSD', 'Gpu': 'Intel HD Graphics 515', 'OpSys': 'Windows 10', 'Weight': '1.2kg', 'Price': 38841.12}
# 1290 : {'_id': ObjectId('68fbb014fdb7463efad72212'), 'Unnamed: 0': 1290, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i3 7100U 2.4GHz', 'Ram': '6GB', 'Memory': '1TB HDD', 'Gpu': 'Intel HD Graphics 620', 'OpSys': 'Windows 10', 'Weight': '2.3kg', 'Price': 24455.52}
# 1291 : {'_id': ObjectId('68fbb014fdb7463efad72213'), 'Unnamed: 0': 1291, 'Company': 'Acer', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Linux', 'Weight': '2.4kg', 'Price': 15397.92}
# 1292 : {'_id': ObjectId('68fbb014fdb7463efad72214'), 'Unnamed: 0': 1292, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '2GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '2.20kg', 'Price': 20193.12}
# 1293 : {'_id': ObjectId('68fbb014fdb7463efad72215'), 'Unnamed: 0': 1293, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'IPS Panel Full HD 1920x1080', 'Cpu': 'Intel Core i7 6700HQ 2.6GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'Nvidia GeForce GTX 960M', 'OpSys': 'Windows 10', 'Weight': '2.6kg', 'Price': 47898.72}
# 1294 : {'_id': ObjectId('68fbb014fdb7463efad72216'), 'Unnamed: 0': 1294, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': 'Full HD 1920x1080', 'Cpu': 'AMD A9-Series 9410 2.9GHz', 'Ram': '6GB', 'Memory': '1.0TB Hybrid', 'Gpu': 'AMD Radeon R7 M440', 'OpSys': 'Windows 10', 'Weight': '2.04kg', 'Price': 29303.4672}
# 1295 : {'_id': ObjectId('68fbb014fdb7463efad72217'), 'Unnamed: 0': 1295, 'Company': 'Dell', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 7500U 2.7GHz', 'Ram': '8GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5 M430', 'OpSys': 'Linux', 'Weight': '2.3kg', 'Price': 42943.1472}
# 1296 : {'_id': ObjectId('68fbb014fdb7463efad72218'), 'Unnamed: 0': 1296, 'Company': 'HP', 'TypeName': 'Netbook', 'Inches': 11.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3060 1.6GHz', 'Ram': '2GB', 'Memory': '32GB Flash Storage', 'Gpu': 'Intel HD Graphics 400', 'OpSys': 'Windows 10', 'Weight': '1.17kg', 'Price': 11135.52}
# 1297 : {'_id': ObjectId('68fbb014fdb7463efad72219'), 'Unnamed: 0': 1297, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Nvidia GeForce 920M', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 38378.6496}
# 1298 : {'_id': ObjectId('68fbb014fdb7463efad7221a'), 'Unnamed: 0': 1298, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 14.0, 'ScreenResolution': 'IPS Panel Full HD / Touchscreen 1920x1080', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '4GB', 'Memory': '128GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.8kg', 'Price': 33992.64}
# 1299 : {'_id': ObjectId('68fbb014fdb7463efad7221b'), 'Unnamed: 0': 1299, 'Company': 'Lenovo', 'TypeName': '2 in 1 Convertible', 'Inches': 13.3, 'ScreenResolution': 'IPS Panel Quad HD+ / Touchscreen 3200x1800', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '16GB', 'Memory': '512GB SSD', 'Gpu': 'Intel HD Graphics 520', 'OpSys': 'Windows 10', 'Weight': '1.3kg', 'Price': 79866.72}
# 1300 : {'_id': ObjectId('68fbb014fdb7463efad7221c'), 'Unnamed: 0': 1300, 'Company': 'Lenovo', 'TypeName': 'Notebook', 'Inches': 14.0, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '2GB', 'Memory': '64GB Flash Storage', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '1.5kg', 'Price': 12201.12}
# 1301 : {'_id': ObjectId('68fbb014fdb7463efad7221d'), 'Unnamed: 0': 1301, 'Company': 'HP', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Core i7 6500U 2.5GHz', 'Ram': '6GB', 'Memory': '1TB HDD', 'Gpu': 'AMD Radeon R5 M330', 'OpSys': 'Windows 10', 'Weight': '2.19kg', 'Price': 40705.92}
# 1302 : {'_id': ObjectId('68fbb014fdb7463efad7221e'), 'Unnamed: 0': 1302, 'Company': 'Asus', 'TypeName': 'Notebook', 'Inches': 15.6, 'ScreenResolution': '1366x768', 'Cpu': 'Intel Celeron Dual Core N3050 1.6GHz', 'Ram': '4GB', 'Memory': '500GB HDD', 'Gpu': 'Intel HD Graphics', 'OpSys': 'Windows 10', 'Weight': '2.2kg', 'Price': 19660.32}

# %%
data_list = list(collection.find())

# %%
new_df = pd.DataFrame(data_list)
new_df.shape , df.shape
# Out:
# ((1303, 13), (1303, 12))

# %%
new_df.head()
# Out:
#                         _id  Unnamed: 0 Company   TypeName  Inches  \
# 0  68fbb014fdb7463efad71d08           0   Apple  Ultrabook    13.3
# 1  68fbb014fdb7463efad71d09           1   Apple  Ultrabook    13.3
# 2  68fbb014fdb7463efad71d0a           2      HP   Notebook    15.6
# 3  68fbb014fdb7463efad71d0b           3   Apple  Ultrabook    15.4
# 4  68fbb014fdb7463efad71d0c           4   Apple  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price
# 0   71378.6832
# 1   47895.5232
# 2   30636.0000
# 3  135195.3360
# 4   96095.8080
